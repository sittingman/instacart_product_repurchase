# %% [markdown]
# # Machine Learning - Modeling (Part 2)

# %% [markdown]
# This section is to repeat the machine learning process by excluding "lags" features.

# %%
import pandas as pd
from pycaret.classification import *

# %%
orders = pd.read_csv('./data/orders.csv')
prior_order = orders.query('eval_set == "prior"')
train_order = orders.query('eval_set == "train"')
test_order = orders.query('eval_set == "test"')

# %%
df = pd.read_csv('./data/df.csv')

# %%
df.head()
# Out:
#    user_id  product_id  last_purchase  reordered     lag  product_appear  \
# 0        1         196            1.0        9.0  20.125             1.0
# 1        1       10258            1.0        8.0  20.125             0.9
# 2        1       10326            0.0        0.0  78.000             0.2
# 3        1       12427            1.0        9.0  20.125             1.0
# 4        1       13032            1.0        2.0  80.500             0.3
#
#    buy_cnt  target
# 0      3.0       1
# 1      3.0       1
# 2      0.0       0
# 3      3.0       0
# 4      1.0       1

# %%
df = df.set_index(['user_id', 'product_id'])

# %% [markdown]
# #### Setup

# %%
exp = setup(df, target='target', categorical_features=['last_purchase'],
            ignore_features=['lag'], train_size=.8)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_99342212_a37f_11ea_aaaf_3cf0112ace06" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row0_col1" class="data row0 col1" >251</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row3_col1" class="data row3 col1" >(9030454, 6)</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T
col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_99342212_a37f_11ea_aaaf_3cf0112ace06level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_99342212_a37f_11ea_aaaf_3cf0112ace06row18_col1" class="data row18 col1" >None</td>
#             </tr>

# %% [markdown]
# #### Compare models
#
# See if any models standout from the F1 score perspective

# %%
compare_models(blacklist=['knn', 'ridge', 'svm', 'lda', 'nb', 'qda', 'et', 'catboost'],
               fold=2, round=3, sort='F1')
# Out:
# <style  type="text/css" >
#     #T_b3ef545c_a381_11ea_80e6_3cf0112ace06 th {
#           text-align: left;
#     }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col0 {
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_b3ef545c_a381_11ea_80e6_3cf0112ace06row6_col6 {
#             : ;
#             text-align:  left;
#         }</style><table id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col1" class="data row0 col1" >0.914000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col2" class="data row0 col2" >0.882000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col3" class="data row0 col3" >0.501000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col4" class="data row0 col4" >0.890000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col5" class="data row0 col5" >0.641000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row0_col6" class="data row0 col6" >0.597000</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col1" class="data row1 col1" >0.914000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col2" class="data row1 col2" >0.882000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace06row1_col3" class="data row1 col3" >0.500000</td>
#                         <td id="T_b3ef545c_a381_11ea_80e6_3cf0112ace0

# %% [markdown]
# **Observation**: Taking out the feature 'lag' overall F1 score stay relatively the same. Extreme Gradient Boosting (Xgboost) become the best performance mode. Trees-based models such as Random Forecast see higher performance boost. We will test out Xgboost and Random Forecast to see if we can achieve the same level of without the 'lag" feature.

# %% [markdown]
# ### Save all the models for final test data submission

# %%
path = './data/save_model/'

def final_save(model, name):
    """ create the final model and save that as pkl file

    Args:
    model: model created with the sample data

    Returns:
    finalize model using all the data
    """

    final = finalize_model(model)
    save_model(final, model_name=path+name)

# %% [markdown]
# ### Tune Model

# %% [markdown]
# We will go straight to the tune model part to optimize for best F1 score.

# %%
rfc_tune = tune_model('rf', fold=2, optimize='F1')
final_save(rfc_tune, 'rfc_tune')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
xbc_tune = tune_model('xgboost', fold=2, n_iter=5, optimize='F1')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
final_save(xbc_tune, 'xbc_tune')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# #### Kaggle Score (tuned model)
#
# | Model | F1 |
# |------| ----|
# | Xgboost | 0.36049 |
# | Random Forecast| 0.36025|
#
# Both models achieved higher F1 score when 'lag' feature is dropped.

# %% [markdown]
# ### Data Submission
#
# Go to [data_sumbit](https://github.com/sittingman/instacart_product_repurchase/blob/master/5_data_submit.ipynb) workbook.
